# %% [markdown]
# # Default notebook
#
# This default notebook is executed using Databricks Workflows as defined in resources/attempt_one.job.yml.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from attempt_one import main

main.get_taxis(spark).show(10)

# %%
dbutils.widgets.text("db", "db_1", "db")

# %%
coso = dbutils.widgets.get("db", "hola")
